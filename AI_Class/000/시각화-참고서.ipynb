# %% [markdown]
# # 시각화 참고서
# 사용한 데이터는 타이타닉 데이터
#
# 데이터는 df라는 변수에 담겨져있다
#
# 데이터를 불러오는 코드는 가장 아래줄에 배치

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 두 컬럼의 관계를 그래프로 그리기
#
# 아래 그림은 age컬럼과 fare컬럼의 관계를 나타낸 것

# %%
df.plot(kind='scatter', x='age', y='fare',  c='coral', s=10, figsize=(10, 5))
plt.show()

# %%
sns.jointplot(x='age', y='fare', data=df)              # 회귀선 없음
sns.jointplot(x='fare', y='pclass', kind='reg', data=df)  # 회귀선 표시
plt.show()
plt.close()

# %% [markdown]
# ## 상관관계 히트맵
#
# 행 방향으로 읽으면 된다.
#
# 색이 진할수록 그 행의 컬럼명과 관계가 높다.

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data = df.corr(), annot=True, 
fmt = '.2f', linewidths=.5, cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 두 컬럼으로 조합해 그릴 수 있는 모든 그래프 그리기

# %%
sns.pairplot(df)  
plt.show()
# Out:
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
import seaborn as sns
df = sns.load_dataset('titanic')
